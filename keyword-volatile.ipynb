// %%
#include <iostream>
std::cout << "Description: This page is about the keyword `volatile` in C++." << std::endl;
// Out:
// In file included from input_line_3:2:
// In file included from /Library/Developer/CommandLineTools/usr/include/c++/v1/iostream:38:
// In file included from /Library/Developer/CommandLineTools/usr/include/c++/v1/ios:215:
// In file included from /Library/Developer/CommandLineTools/usr/include/c++/v1/iosfwd:90:
// In file included from /Library/Developer/CommandLineTools/usr/include/c++/v1/wchar.h:119:
// In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include/wchar.h:90:
// In file included from /Library/Developer/CommandLineTools/usr/include/c++/v1/stdio.h:108:
// In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include/stdio.h:64:
// In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include/_stdio.h:79:
// /Library/Developer/CommandLineTools/SDKs/MacOSX10.14.sdk/usr/include/sys/stdio.h:37:1: error: expected unqualified-id
// __BEGIN_DECLS
// ^
// ...

// %%
{
    volatile bool myStateCheck;
    myStateCheck = false;
    while (myStateCheck) {
        //std::cout << "Running state check code" << std::endl;
    }
}

// %%
std::cout << "Question 1: What is the `volatile` keyword in C++?" << std::endl;
std::cout << "Answer   1: `volatile` indicates an object's value might change spontaneously even if the program does not seem to change it. This tells the compiler to not optimize away code." << std::endl;
// Out:
// input_line_7:2:7: error: no member named 'cout' in namespace 'std'
//  std::cout << "Question 1: What is the `volatile` keyword in C++?" << std::endl;
//  ~~~~~^
// input_line_7:2:76: error: no member named 'endl' in namespace 'std'
//  std::cout << "Question 1: What is the `volatile` keyword in C++?" << std::endl;
//                                                                       ~~~~~^
// input_line_7:3:6: error: no member named 'cout' in namespace 'std'
// std::cout << "Answer   1: `volatile` indicates an object's value might change spontaneously even if the program doe...
// ~~~~~^
// input_line_7:3:201: error: no member named 'endl' in namespace 'std'
//   ...even if the program does not seem to change it. This tells the compiler to not optimize away code." << std::endl;
//                                                                                                             ~~~~~^
// ename: evalue
